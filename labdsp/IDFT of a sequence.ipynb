# %%
import numpy as np
import matplotlib.pyplot as plt

# Input X(K)
Xk = np.array(input('Enter X(K) (comma-separated): ').split(','), dtype=complex)
N = len(Xk)

xn = np.zeros(N, dtype=complex)
k = np.arange(0, N)
for n in range(N):
    xn[n] = np.sum(np.exp(1j * 2 * np.pi * k * n / N) * Xk)

xn = xn / N

print('x(n):')
print(xn)

plt.figure()
plt.plot(np.real(xn))
plt.grid(True)
plt.stem(k, np.real(xn))
plt.xlabel('n')
plt.ylabel('Magnitude')
plt.title('IDFT OF A SEQUENCE')

plt.tight_layout()
plt.show()
# Out:
# Enter X(K) (comma-separated):  3,4,2,4,5,6,3,4
# x(n):
# [ 3.875    +0.00000000e+00j -0.4267767-3.01776695e-01j
#   0.375    +2.50000000e-01j -0.0732233-5.17766953e-02j
#  -0.625    +4.89858720e-16j -0.0732233+5.17766953e-02j
#   0.375    -2.50000000e-01j -0.4267767+3.01776695e-01j]
